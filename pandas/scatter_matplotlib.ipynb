# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_athletes = pd.read_csv('data/bios.csv')

# %%
df_athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
df_athletes.dropna(subset=['height_cm', 'weight_kg', 'born_date'], inplace=True)

# %%
df_athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101977 entries, 1 to 145497
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    101977 non-null  int64
#  1   name          101977 non-null  object
#  2   born_date     101977 non-null  object
#  3   born_city     81896 non-null   object
#  4   born_region   81896 non-null   object
#  5   born_country  81896 non-null   object
#  6   NOC           101977 non-null  object
#  7   height_cm     101977 non-null  float64
#  8   weight_kg     101977 non-null  float64
#  9   died_date     12340 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 8.6+ MB

# %%
df_athletes["born_year"] = pd.to_datetime(df_athletes["born_date"]).dt.year

# %%
df_mens = df_athletes[['height_cm', 'weight_kg', 'born_year']]

# %%
df_mens.sort_values(by=['height_cm', 'weight_kg'], inplace=True)
# Out:
# C:\Users\aarnoux\AppData\Local\Temp\ipykernel_16504\4065528808.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mens.sort_values(by=['height_cm', 'weight_kg'], inplace=True)

# %%
df_mens
# Out:
#        height_cm  weight_kg  born_year
# 28619      127.0       42.0       1953
# 4515       127.0       62.0       1963
# 4516       128.0       74.0       1967
# 4664       130.0       51.0       1949
# 4517       130.0       67.0       1959
# ...          ...        ...        ...
# 5673       221.0      114.0       1963
# 89075      221.0      137.0       1975
# 5781       223.0      102.0       1952
# 6978       223.0      122.0       1964
# 89070      226.0      141.0       1980
#
# [101977 rows x 3 columns]

# %%
plt.scatter(df_mens['weight_kg'], df_mens['height_cm'], color="orange", alpha=0.2, s=20)
plt.ylabel('Height (cm)')
plt.xlabel('Weight (kg)')
plt.title('Height vs Weight of Olympic Athletes')
# Out:
# Text(0.5, 1.0, 'Height vs Weight of Olympic Athletes')

# %%
plt.scatter(x='weight_kg', y='height_cm', data=df_mens, c='born_year', cmap='rainbow', alpha=.5, s=15, vmin=df_mens["born_year"].min(), vmax=df_mens["born_year"].max())
plt.ylabel('Height (cm)')
plt.xlabel('Weight (kg)')
plt.title('Height vs Weight of Olympic Athletes')
plt.colorbar(label='Born Year')
plt.grid(linestyle='--', alpha=0.5)
